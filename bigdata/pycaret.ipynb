# %%
# when use mac / install xgboost
# https://joylife052.tistory.com/entry/XGBoost-eXtra-Gradient-Boost-%EC%84%A4%EC%B9%98
# pip install pycaret

# %% [markdown]
# # AutoML

# %%
import pandas as pd

# %%
df = pd.read_csv("./dataset/train.csv")

# %%
from pycaret.classification import *
exp1 = setup(df, target = 'Survived',
            ignore_features=['PassengerId'])
# Out:
# <style type="text/css">
# #T_3762c_row5_col1, #T_3762c_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3762c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3762c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3762c_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_3762c_row0_col1" class="data row0 col1" >7025</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3762c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3762c_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3762c_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_3762c_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3762c_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_3762c_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3762c_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_3762c_row4_col1" class="data row4 col1" >(891, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3762c_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_3762c_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3762c_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_3762c_row6_col1" class="data row6 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3762c_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_3762c_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3762c_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_3762c_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3762c_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_3762c_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3762c_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_3762c_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3762c_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_3762c_row11_col1" class="data row11 col1" >(623, 710)</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3762c_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_3762c_row12_col1" class="data row12 col1" >(268, 710)</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3762c_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_3762c_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3762c_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_3762c_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3762c_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_3762c_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3762c_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_3762c_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3762c_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_3762c_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3762c_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_3762c_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_3762c_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_3762c_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_3762c_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_3762c_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_3762c_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_3762c_row21_col1" class="data row21 col1" >38a6</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_3762c_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_3762c_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_3762c_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_3762c_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_3762c_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_3762c_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_3762c_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_3762c_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_3762c_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_3762c_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_3762c_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_3762c_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_3762c_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_3762c_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_3762c_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_3762c_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3762c_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_3762c_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_3762c_row30_col1" class="data row30 col1" >None</td>

# %%
top5 = compare_models(n_select=5)
# Out:
# <style type="text/css">
# #T_ca69e_ th {
#   text-align: left;
# }
# #T_ca69e_row0_col0, #T_ca69e_row0_col2, #T_ca69e_row0_col3, #T_ca69e_row0_col4, #T_ca69e_row1_col0, #T_ca69e_row1_col1, #T_ca69e_row1_col2, #T_ca69e_row1_col3, #T_ca69e_row1_col5, #T_ca69e_row1_col6, #T_ca69e_row1_col7, #T_ca69e_row2_col0, #T_ca69e_row2_col1, #T_ca69e_row2_col2, #T_ca69e_row2_col3, #T_ca69e_row2_col4, #T_ca69e_row2_col5, #T_ca69e_row2_col6, #T_ca69e_row2_col7, #T_ca69e_row3_col0, #T_ca69e_row3_col1, #T_ca69e_row3_col2, #T_ca69e_row3_col3, #T_ca69e_row3_col4, #T_ca69e_row3_col5, #T_ca69e_row3_col6, #T_ca69e_row3_col7, #T_ca69e_row4_col0, #T_ca69e_row4_col1, #T_ca69e_row4_col3, #T_ca69e_row4_col4, #T_ca69e_row4_col5, #T_ca69e_row4_col6, #T_ca69e_row4_col7, #T_ca69e_row5_col0, #T_ca69e_row5_col1, #T_ca69e_row5_col2, #T_ca69e_row5_col3, #T_ca69e_row5_col4, #T_ca69e_row5_col5, #T_ca69e_row5_col6, #T_ca69e_row5_col7, #T_ca69e_row6_col0, #T_ca69e_row6_col1, #T_ca69e_row6_col2, #T_ca69e_row6_col3, #T_ca69e_row6_col4, #T_ca69e_row6_col5, #T_ca69e_row6_col6, #T_ca69e_row6_col7, #T_ca69e_row7_col0, #T_ca69e_row7_col1, #T_ca69e_row7_col2, #T_ca69e_row7_col3, #T_ca69e_row7_col4, #T_ca69e_row7_col5, #T_ca69e_row7_col6, #T_ca69e_row7_col7, #T_ca69e_row8_col0, #T_ca69e_row8_col1, #T_ca69e_row8_col2, #T_ca69e_row8_col3, #T_ca69e_row8_col4, #T_ca69e_row8_col5, #T_ca69e_row8_col6, #T_ca69e_row8_col7, #T_ca69e_row9_col0, #T_ca69e_row9_col1, #T_ca69e_row9_col2, #T_ca69e_row9_col3, #T_ca69e_row9_col4, #T_ca69e_row9_col5, #T_ca69e_row9_col6, #T_ca69e_row9_col7, #T_ca69e_row10_col0, #T_ca69e_row10_col1, #T_ca69e_row10_col2, #T_ca69e_row10_col3, #T_ca69e_row10_col4, #T_ca69e_row10_col5, #T_ca69e_row10_col6, #T_ca69e_row10_col7, #T_ca69e_row11_col0, #T_ca69e_row11_col1, #T_ca69e_row11_col2, #T_ca69e_row11_col3, #T_ca69e_row11_col4, #T_ca69e_row11_col5, #T_ca69e_row11_col6, #T_ca69e_row11_col7, #T_ca69e_row12_col0, #T_ca69e_row12_col1, #T_ca69e_row12_col2, #T_ca69e_row12_col3, #T_ca69e_row12_col4, #T_ca69e_row12_col5, #T_ca69e_row12_col6, #T_ca69e_row12_col7, #T_ca69e_row13_col0, #T_ca69e_row13_col1, #T_ca69e_row13_col2, #T_ca69e_row13_col4, #T_ca69e_row13_col5, #T_ca69e_row13_col6, #T_ca69e_row13_col7 {
#   text-align: left;
# }
# #T_ca69e_row0_col1, #T_ca69e_row0_col5, #T_ca69e_row0_col6, #T_ca69e_row0_col7, #T_ca69e_row1_col4, #T_ca69e_row4_col2, #T_ca69e_row13_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ca69e_row0_col8, #T_ca69e_row1_col8, #T_ca69e_row2_col8, #T_ca69e_row3_col8, #T_ca69e_row4_col8, #T_ca69e_row5_col8, #T_ca69e_row6_col8, #T_ca69e_row7_col8, #T_ca69e_row8_col8, #T_ca69e_row9_col8, #T_ca69e_row11_col8, #T_ca69e_row12_col8, #T_ca69e_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ca69e_row10_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ca69e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca69e_level0_row0" class="row_heading level0 row0" >ridge</th>
#       <td id="T_ca69e_row0_col0" class="data row0 col0" >Ridge Classifier</td>
#       <td id="T_ca69e_row0_col1" class="data row0 col1" >0.8106</td>
#       <td id="T_ca69e_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_ca69e_row0_col3" class="data row0 col3" >0.6937</td>
#       <td id="T_ca69e_row0_col4" class="data row0 col4" >0.7857</td>
#       <td id="T_ca69e_row0_col5" class="data row0 col5" >0.7318</td>
#       <td id="T_ca69e_row0_col6" class="data row0 col6" >0.5871</td>
#       <td id="T_ca69e_row0_col7" class="data row0 col7" >0.5942</td>
#       <td id="T_ca69e_row0_col8" class="data row0 col8" >0.0220</td>
#     </tr>
#     <tr>
#       <th id="T_ca69e_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_ca69e_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_ca69e_row1_col1" class="data row1 col1" >0.8090</td>
#       <td id="T_ca69e_row1_col2" class="data row1 col2" >0.8523</td>
#       <td id="T_ca69e_row1_col3" class="data row1 col3" >0.6514</td>
#       <td id="T_ca69e_row1_col4" class="data row1 col4" >0.8132</td>
#       <td id="T_ca69e_row1_col5" class="data row1 col5" >0.7174</td>
#       <td id="T_ca69e_row1_col6" class="data row1 col6" >0.5768</td>
#       <td id="T_ca69e_row1_col7" class="data row1 col7" >0.5893</td>
#       <td id="T_ca69e_row1_col8" class="data row1 col8" >0.2150</td>
#     </tr>
#     <tr>
#       <th id="T_ca69e_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_ca69e_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_ca69e_row2_col1" class="data row2 col1" >0.8026</td>
#       <td id="T_ca69e_row2_col2" class="data row2 col2" >0.8579</td>
#       <td id="T_ca69e_row2_col3" class="data row2 col3" >0.6980</td>
#       <td id="T_ca69e_row2_col4" class="data row2 col4" >0.7657</td>
#       <td id="T_ca69e_row2_col5" class="data row2 col5" >0.7249</td>
#       <td id="T_ca69e_row2_col6" class="data row2 col6" >0.5722</td>
#       <td id="T_ca69e_row2_col7" class="data row2 col7" >0.5786</td>
#       <td id="T_ca69e_row2_col8" class="data row2 col8" >0.4970</td>
#     </tr>
#     <tr>
#       <th id="T_ca69e_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_ca69e_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ca69e_row3_col1" class="data row3 col1" >0.8009</td>
#       <td id="T_ca69e_row3_col2" class="data row3 col2" >0.8531</td>
#       <td id="T_ca69e_row3_col3" class="data row3 col3" >0.6844</td>
#       <td id="T_ca69e_row3_col4" class="data row3 col4" >0.7836</td>
#       <td id="T_ca69e_row3_col5" class="data row3 col5" >0.7199</td>
#       <td id="T_ca69e_row3_col6" class="data row3 col6" >0.5674</td>
#       <td id="T_ca69e_row3_col7" class="data row3 col7" >0.5805</td>
#       <td id="T_ca69e_row3_col8" class="data row3 col8" >0.0350</td>
#     </tr>
#     <tr>
#       <th id="T_ca69e_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_ca69e_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_ca69e_row4_col1" class="data row4 col1" >0.7993</td>
#       <td id="T_ca69e_row4_col2" class="data row4 col2" >0.8615</td>
#       <td id="T_ca69e_row4_col3" class="data row4 col3" >0.6295</td>
#       <td id="T_ca69e_row4_col4" class="data row4 col4" >0.8127</td>
#       <td id="T_ca69e_row4_col5" class="data row4 col5" >0.6995</td>
#       <td id="T_ca69e_row4_col6" class="data row4 col6" >0.5536</td>
#       <td id="T_ca69e_row4_col7" class="data row4 col7" >0.5710</td>
#       <td id="T_ca69e_row4_col8" class="data row4 col8" >0.2100</td>
#     </tr>
#     <tr>
#       <th id="T_ca69e_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_ca69e_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_ca69e_row5_col1" class="data row5 col1" >0.7914</td>
#       <td id="T_ca69e_row5_col2" class="data row5 col2" >0.7661</td>
#       <td id="T_ca69e_row5_col3" class="data row5 col3" >0.6636</td>
#       <td id="T_ca69e_row5_col4" class="data row5 col4" >0.7651</td>
#       <td id="T_ca69e_row5_col5" class="data row5 col5" >0.6996</td>
#       <td id="T_ca69e_row5_col6" class="data row5 col6" >0.5430</td>
#       <td id="T_ca69e_row5_col7" class="data row5 col7" >0.5551</td>
#       <td id="T_ca69e_row5_col8" class="data row5 col8" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_ca69e_level0_row6" class="row_heading level0 row6" >gbc</th>
#       <td id="T_ca69e_row6_col0" class="data row6 col0" >Gradient Boost

# %%
top5
# Out:
# [RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                  max_iter=None, normalize=False, random_state=7025,
#                  solver='auto', tol=0.001),
#  ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                       criterion='gini', max_depth=None, max_features='auto',
#                       max_leaf_nodes=None, max_samples=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                       oob_score=False, random_state=7025, verbose=0,
#                       warm_start=False),
#  LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                     intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                     multi_class='auto', n_jobs=None, penalty='l2',
#                     random_state=7025, solver='lbfgs', tol=0.0001, verbose=0,
#                     warm_start=False),
#  LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                 importance_type='split', learning_rate=0.1, max_depth=-1,
#                 min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                 n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                 random_state=7025, reg_alpha=0.0, reg_lambda=0.0, silent='warn',
#                 subsample=1.0, subsample_for_bin=200000, subsample_freq=0),
#  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                         criterion='gini', max_depth=None, max_features='auto',
#                         max_leaf_nodes=None, max_samples=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, n_estimators=100,
#                         n_jobs=-1, oob_score=False, random_state=7025, verbose=0,
#                         warm_start=False)]
