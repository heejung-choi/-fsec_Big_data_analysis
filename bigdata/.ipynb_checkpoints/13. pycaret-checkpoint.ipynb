# %%
# when use mac / install xgboost
# https://joylife052.tistory.com/entry/XGBoost-eXtra-Gradient-Boost-%EC%84%A4%EC%B9%98
# pip install pycaret
# pycaret 은 미리 screen 하는 용도, 어떤 데이터를 분석할 때 전처리 하지 않아도 우선 어떤 분석이 필요할지 확인 할 수 있게 해준다.
# 그런데.. CPU가 너무 많이 소비가 되기 때문에 힘들 수 있다.

# %% [markdown]
# # AutoML

# %%
import pandas as pd

# %%
df = pd.read_csv("./dataset/train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
from pycaret.classification import *
exp1 = setup(df, target = 'Survived',
            ignore_features=['PassengerId'])
#setup에 설정 옵션 바꿀 수 있다.
# Out:
# <style type="text/css">
# #T_7c9c7_row5_col1, #T_7c9c7_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7c9c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c9c7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7c9c7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c9c7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c9c7_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_7c9c7_row0_col1" class="data row0 col1" >8254</td>
#     </tr>
#     <tr>
#       <th id="T_7c9c7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7c9c7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7c9c7_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
#       <th id="T_7c9c7_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
top5 = compare_models(n_select=5)
# 모델 성능을 비교하고 그중에서 가장 성능이 좋은 5가지를 저장시킨다.
# Out:
# <style type="text/css">
# #T_06075 th {
#   text-align: left;
# }
# ...

# %%
top5
# Out:
# [RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                  max_iter=None, normalize=False, random_state=8254,
#                  solver='auto', tol=0.001),
#  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                         criterion='gini', max_depth=None, max_features='auto',
#                         max_leaf_nodes=None, max_samples=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, n_estimators=100,
#                         n_jobs=-1, oob_score=False, random_state=8254, verbose=0,
#                         warm_start=False),
#  ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                       criterion='gini', max_depth=None, max_features='auto',
#                       max_leaf_nodes=None, max_samples=None,
# ...

# %%
top5[0]
# Out:
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, normalize=False, random_state=8254,
#                 solver='auto', tol=0.001)
